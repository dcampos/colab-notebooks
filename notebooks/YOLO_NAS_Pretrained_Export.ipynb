# %%
! pip install -q git+https://github.com/Deci-AI/super-gradients.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Building wheel for super-gradients (pyproject.toml) ... done
#   Building wheel for onnx (pyproject.toml) ... done
#   Building wheel for termcolor (setup.py) ... done
#   Building wheel for treelib (setup.py) ... done
#   Building wheel for xhtml2pdf (setup.py) ... done
#   Building wheel for onnxsim (setup.py) ... done
#   Building wheel for stringcase (setup.py) ... done
#   Building wheel for coverage (setup.py) ... done
#   Building wheel for reportlab (setup.py) ... done
#   Building wheel for svglib (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.

# %%
! pip install onnx onnxruntime onnxsim onnxscript
# Out:
# Requirement already satisfied: onnx in /usr/local/lib/python3.12/dist-packages (1.20.1)
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.12/dist-packages (1.23.2)
# Requirement already satisfied: onnxsim in /usr/local/lib/python3.12/dist-packages (0.4.36)
# Requirement already satisfied: onnxscript in /usr/local/lib/python3.12/dist-packages (0.5.7)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from onnx) (2.0.2)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (5.29.5)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx) (0.5.4)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (25.12.19)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (25.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (1.14.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from onnxsim) (13.9.4)
# Requirement already satisfied: onnx_ir<2,>=0.1.12 in /usr/local/lib/python3.12/dist-packages (from onnxscript) (0.1.15)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->onnxsim) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->onnxsim) (2.19.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->onnxsim) (0.1.2)

# %%
import sys
python_version = f"python{sys.version_info.major}.{sys.version_info.minor}"


! sed -i 's/sghub.deci.ai/sg-hub-nv.s3.amazonaws.com/' /usr/local/lib/{python_version}/dist-packages/super_gradients/training/pretrained_models.py
! sed -i 's/sghub.deci.ai/sg-hub-nv.s3.amazonaws.com/' /usr/local/lib/{python_version}/dist-packages/super_gradients/training/utils/checkpoint_utils.py

# %%
from super_gradients.common.object_names import Models
from super_gradients.conversion import DetectionOutputFormatMode
from super_gradients.training import models

model = models.get(Models.YOLO_NAS_S, pretrained_weights="coco")
# Out:
# The console stream is logged into /root/sg_logs/console.log
# [2026-01-23 20:32:37] INFO - crash_tips_setup.py - Crash tips is enabled. You can set your environment variable to CRASH_HANDLER=FALSE to disable it
# [2026-01-23 20:32:45] INFO - utils.py - NumExpr defaulting to 2 threads.
# DEBUG:2026-01-23 20:32:53,370:jax._src.path:41: etils.epath found. Using etils.epath for file I/O.
# /usr/local/lib/python3.12/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.24). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# [2026-01-23 20:33:01] INFO - env_sanity_check.py - Library check is not supported when super_gradients installed through "git+https://github.com/..." command
# [2026-01-23 20:33:02] WARNING - checkpoint_utils.py - :warning: The pre-trained models provided by SuperGradients may have their own licenses or terms and conditions derived from the dataset used for pre-training.
#  It is your responsibility to determine whether you have permission to use the models for your use case.
#  The model you have requested was pre-trained on the coco dataset, published under the following terms: https://cocodataset.org/#termsofuse
# [2026-01-23 20:33:02] INFO - checkpoint_utils.py - License Notification: YOLO-NAS pre-trained weights are subjected to the specific license terms and conditions detailed in
# https://github.com/Deci-AI/super-gradients/blob/master/LICENSE.YOLONAS.md
# By downloading the pre-trained weight files you agree to comply with these terms.
# [2026-01-23 20:33:02] INFO - checkpoint_utils.py - Successfully loaded pretrained weights for architecture yolo_nas_s

# %%
# export the model for compatibility with Frigate

# Downgrade onnx to a compatible version
! pip install onnx==1.12.0

model.export("yolo_nas_s.onnx",
             output_predictions_format=DetectionOutputFormatMode.FLAT_FORMAT,
             max_predictions_per_image=20,
             num_pre_nms_predictions=300,
             confidence_threshold=0.4,
             input_image_shape=(320,320),
            )
# Out:
# Collecting onnx==1.12.0
#   Downloading onnx-1.12.0.tar.gz (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 35.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.12/dist-packages (from onnx==1.12.0) (2.0.2)
# Collecting protobuf<=3.20.1,>=3.12.2 (from onnx==1.12.0)
#   Downloading protobuf-3.20.1-py2.py3-none-any.whl.metadata (720 bytes)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.12/dist-packages (from onnx==1.12.0) (4.15.0)
# Downloading protobuf-3.20.1-py2.py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 11.7 MB/s eta 0:00:00
# Building wheels for collected packages: onnx
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for onnx (setup.py) ... error
#   ERROR: Failed building wheel for onnx
#   Running setup.py clean for onnx
# Failed to build onnx
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (onnx)
# [2026-01-23 20:35:20] INFO - unused_removal.py - Removed 874 unused nodes
# [2026-01-23 20:35:20] INFO - unused_removal.py - No unused functions to remove
# [2026-01-23 20:35:20] INFO - _constant_folding.py - Skipping constant folding for node 'node__to_copy' because it is graph input to preserve graph signature
# [2026-01-23 20:35:21] INFO - unused_removal.py - Removed 635 unused nodes
# [2026-01-23 20:35:21] INFO - unused_removal.py - No unused functions to remove
# [2026-01-23 20:35:21] INFO - _constant_folding.py - Skipping constant folding for node 'node__to_copy' because it is graph input to preserve graph signature
# [2026-01-23 20:35:21] INFO - unused_removal.py - Removed 4 unused nodes
# [2026-01-23 20:35:21] INFO - unused_removal.py - No unused functions to remove
# Applied 151 of general pattern rewrite rules.
# [2026-01-23 20:35:21] INFO - initializer_deduplication.py - Replaced initializer 'val_645' with existing initializer 'val_604'
# [2026-01-23 20:35:21] INFO - initializer_deduplication.py - Replaced initializer 'val_686' with existing initializer 'val_604'
# [2026-01-23 20:35:21] INFO - initializer_deduplication.py - Replaced initializer 'val_932' with existing initializer 'val_942'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2632479442.py in <cell line: 0>()
#       4 get_ipython().system(' pip install onnx==1.12.0')
#       5
# ----> 6 model.export("yolo_nas_s.onnx",
#       7              output_predictions_format=DetectionOutputFormatMode.FLAT_FORMAT,
#       8              max_predictions_per_image=20,
#
# /usr/local/lib/python3.12/dist-packages/super_gradients/module_interfaces/exportable_detector.py in export(self, output, confidence_threshold, nms_threshold, engine, quantization_mode, selective_quantizer, calibration_loader, calibration_method, calibration_batches, calibration_percentile, preprocessing, postprocessing, postprocessing_kwargs, batch_size, input_image_shape, input_image_channels, input_image_dtype, max_predictions_per_image, onnx_export_kwargs, onnx_simplify, device, output_predictions_format, num_pre_nms_predictions)
#     499                     raise KeyError(f"Unsupported engine: {engine}")
#     500
# --> 501                 nms_attach_method(
#     502                     onnx_model_path=output,
#     503                     output_onnx_model_path=output,
#
# /usr/local/lib/python3.12/dist-packages/super_gradients/conversion/onnx/nms.py in attach_onnx_nms(onnx_model_path, output_onnx_model_path, num_pre_nms_predictions, max_predictions_per_image, confidence_threshold, nms_threshold, batch_size, output_predictions_format, device, onnx_export_kwargs)
#     310     :return: None
#     311     """
# --> 312     graph = gs.import_onnx(onnx.load(onnx_model_path))
#     313
#     314     pred_boxes, pred_scores = graph.outputs
#
# /usr/local/lib/python3.12/dist-packages/onnx_graphsurgeon/importers/onnx_importer.py in import_onnx(onnx_model)
#     335         Graph: A corresponding onnx-graphsurgeon Graph.
#     336     """
# --> 337     return OnnxImporter.import_graph(
#     338         onnx_model.graph,
#     339         opset=OnnxImporter.get_opset(onnx_model),
#
# /usr/local/lib/python3.12/dist-packages/onnx_graphsurgeon/importers/onnx_importer.py in import_graph(onnx_graph, tensor_map, opset, import_domains, producer_name, producer_version)
#     281         G_LOGGER.verbose("Importing initializers")
#     282         for initializer in onnx_graph.initializer:
# --> 283             get_tensor(initializer)
#     284
#     285         # Import all tensors whose shapes are known. Tensors may be repeated, and some of these
#
# /usr/local/lib/python3.12/dist-packages/onnx_graphsurgeon/importers/onnx_importer.py in get_tensor(onnx_tensor, overwrite, check_outer_graph)
#     275                 return tensor_map[onnx_tensor.name]
#     276
# --> 277             subgraph_tensor_map[onnx_tensor.name] = OnnxImporter.import_tensor(onnx_tensor)
#     278             return subgraph_tensor_map[onnx_tensor.name]
#     279
#
# /usr/local/lib/python3.12/dist-packages/onnx_graphsurgeon/importers/onnx_importer.py in import_tensor(onnx_tensor)
#     130         if isinstance(onnx_tensor, onnx.TensorProto):
#     131             data_location = int(onnx_tensor.data_location) if onnx_tensor.HasField("data_location") else None
# --> 132             return Constant(name=onnx_tensor.name, values=LazyValues(onnx_tensor), data_location=data_location)
#     133         else:
#     134             return Variable(
#
# /usr/local/lib/python3.12/dist-packages/onnx_graphsurgeon/ir/tensor.py in __init__(self, tensor)
#     206         self.tensor = tensor
#     207         self.shape = get_onnx_tensor_shape(self.tensor)
# --> 208         self.dtype = get_onnx_tensor_dtype(self.tensor)
#     209         self.nbytes = misc.volume(self.shape) * get_itemsize(self.dtype)
#     210
#
# /usr/local/lib/python3.12/dist-packages/onnx_graphsurgeon/importers/onnx_importer.py in get_onnx_tensor_dtype(onnx_tensor)
#      97         onnx_type = onnx_tensor.type.tensor_type.elem_type
#      98
# ---> 99     dtype = get_numpy_type(onnx_type)
#     100     if dtype is not None:
#     101         return dtype
#
# /usr/local/lib/python3.12/dist-packages/onnx_graphsurgeon/importers/onnx_importer.py in get_numpy_type(onnx_type)
#      84     # For some reason, TENSOR_TYPE_TO_NP_TYPE maps `bfloat16` to `float32`.
#      85     # This obviously breaks things, so we need to treat this as a special case.
# ---> 86     if onnx_type != onnx.TensorProto.BFLOAT16 and onnx_type in onnx.mapping.TENSOR_TYPE_TO_NP_TYPE:
#      87         return onnx.mapping.TENSOR_TYPE_TO_NP_TYPE[onnx_type]
#      88     return None
#
# AttributeError: module 'onnx' has no attribute 'mapping'

# %%
from google.colab import files

files.download('yolo_nas_s.onnx')
